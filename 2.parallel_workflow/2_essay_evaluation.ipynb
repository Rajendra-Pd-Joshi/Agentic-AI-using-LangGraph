# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from typing import Annotated
import operator

# %%
class EssayState(TypedDict):
    essay: str
    language_feedback: str
    clarity_of_thought_feedback: str
    in_depth_analysis_feedback: str

    feedback_summary: str
    individual_score: Annotated[list[int],operator.add]

    average_score: float

# %%
model = ChatOpenAI(model = 'gpt-4o-mini')

# %%
# create one model with structured output
from pydantic import BaseModel,Field


class schema(BaseModel):
    feedback: str = Field(description='give a detailed feedback of an essay')
    score: int = Field(description='a score btween 0 to 10 by analyzing the essay',ge=0,le=10)

# %%
structured_model = model.with_structured_output(schema=schema)

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
structured_model.invoke(input=essay)
# Out:
# schema(feedback="The essay presents a well-structured and comprehensive analysis of the opportunities and challenges faced by India in the age of artificial intelligence (AI). It effectively highlights India's strengths, such as its pool of skilled engineers and burgeoning AI startup ecosystem, while also scrutinizing the significant obstacles, including the digital divide and concerns surrounding data privacy. \n\nStrengths:\n1. **Clarity and Structure**: The essay is organized into distinct sections that flow logically from one idea to another, making it easy for the reader to follow. The introduction sets the stage and the conclusion succinctly summarizes the key points while reiterating the importance of responsible AI integration.\n2. **Use of Examples**: The writer effectively uses relevant examples (e.g., AI in agriculture, healthcare, and education) to illustrate the potential of AI in transforming key sectors within India. This not only strengthens the argument but also grounds the essay in real-world applications.\n3. **Balanced Perspective**: The writer successfully balances optimism about AI's potential with a critical examination of the risks involved, particularly concerning social inequalities and ethical concerns. This nuanced approach adds depth to the analysis.\n4. **Call for Collaboration**: The proposal for a multi-stakeholder approach and international collaboration underlines a pragmatic strategy for tackling the challenges ahead and emphasizes the need for responsible governance in the AI landscape.\n\nAreas for Improvement:\n1. **Elaboration on Challenges**: While the essay mentions challenges like job displacement and the digital divide, additional elaboration or specific examples could strengthen these points. Providing statistics or case studies regarding the impact of automation on jobs would enhance the argument.\n2. **Data Privacy Discussion**: The section on data privacy could benefit from more depth. Including specific existing regulations (or lack thereof) and their implications on AI practices would provide a clearer picture of the current landscape in India.\n3. **Cohesion**: While each section is strong on its own, some transitions between paragraphs can be strengthened to improve overall cohesion. This would help to tie the narrative together more tightly and lead the reader through the argument seamlessly.\n4. **Future Outlook**: A more detailed projection of what India's AI landscape might look like in the next 5 to 10 years, considering both the opportunities and challenges, could enhance the concluding remarks. This could include potential scenarios depending on various policy choices or economic developments.\n\nOverall, this essay effectively addresses a critical topic. A few enhancements in detail and cohesion will make the argument even more compelling and impactful.", score=8)

# %%
graph = StateGraph(state_schema=EssayState)

# %%
def evaluate_analysis(state:EssayState):
     prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'

     output = structured_model.invoke(prompt)

     return {'in_depth_analysis_feedback': output.feedback,'individual_score':[output.score]}

# %%
def evaluate_language(state:EssayState):
     prompt = f'Evaluate the language of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'

     output = structured_model.invoke(prompt)

     return {'language_feedback': output.feedback,'individual_score':[output.score]}

# %%
def evaluate_clarity_of_thought(state:EssayState):
     prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'

     output = structured_model.invoke(prompt)

     return {'clarity_of_thought_feedback': output.feedback,'individual_score':[output.score]}

# %%
def final_feedback(state:EssayState):
    prompt = f"give the final feedback of the essay by summarizing the individual feedbacks and scores \n {state['language_feedback']} \n {state['clarity_of_thought_feedback']} \n {state['in_depth_analysis_feedback']}   "
    output = model.invoke(prompt)

    # avg score
    avg_score = sum(state['individual_score'])/len(state['individual_score'])
    return {"feedback_summary": output, "average_score": avg_score}

# %%
graph.add_node('evaluate_analysis',evaluate_analysis)
graph.add_node('evaluate_language',evaluate_language)
graph.add_node('evaluate_clarity_of_thought',evaluate_clarity_of_thought)
graph.add_node('final_feedback',final_feedback)


graph.add_edge(START,'evaluate_analysis')
graph.add_edge(START,'evaluate_language')
graph.add_edge(START,'evaluate_clarity_of_thought')

graph.add_edge('evaluate_analysis','final_feedback')
graph.add_edge('evaluate_language','final_feedback')
graph.add_edge('evaluate_clarity_of_thought','final_feedback')

graph.add_edge('final_feedback',END)

workflow = graph.compile()

# %%
workflow.invoke(input={"essay":essay})
# Out:
# {'essay': "India in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.",
#  'language_feedback': 'The essay entitled \'India in the Age of AI\' articulately discusses the potential of artificial intelligence in shaping India\'s future, covering both its opportunities and challenges. The language is formal and academic, suitable for the subject matter, and it flows logically from one point to the next. Here is a detailed breakdown of the strengths and areas for improvement:\n\n**Strengths:**\n1. **Clarity and Structure:** The essay is well-structured, featuring a clear introduction, body, and conclusion. Each section transitions smoothly to the next, maintaining the reader\'s engagement.\n2. **Depth of Analysis:** The author provides a comprehensive analysis of India’s current status in the AI landscape, highlighting both the strengths (such as the skilled workforce and government initiatives) and the challenges (like the digital divide and ethical concerns). This balanced viewpoint enhances the credibility of the discussion.\n3. **Use of Examples:** The inclusion of specific examples, such as the impact of AI on agriculture and healthcare, strengthens the argument by illustrating real-world applications of AI in India. This adds practical relevance to theoretical discussions.\n4. **Call to Action:** The conclusion effectively summarizes the main points and makes a compelling case for a responsible approach to AI adoption, emphasizing the importance of multi-stakeholder involvement.\n\n**Areas for Improvement:**\n1. **Language Precision:** While the language is generally strong, there are moments where simpler phrasing could enhance readability. For instance, terms like "burgeoning base" could be replaced with "growing number" for clarity.\n2. **Citations and References:** The essay could benefit from references to statistics, studies, or quotes from credible sources to further substantiate claims, especially when discussing the digital divide or data privacy issues.\n3. **Elaboration on Data Privacy:** The section discussing data privacy and ethics is important but could use more depth. Providing examples of recent data breaches or ethical dilemmas facing AI systems in India could strengthen this part of the argument.\n4. **Editing for Conciseness:** Some sentences are a bit lengthy, which may affect readability. For example, breaking up complex sentences into simpler statements might improve comprehension.\n\nOverall, the essay is insightful and presents a thorough examination of India\'s position in the age of AI. With minor revisions for clarity and additional evidence, it would be even stronger.',
#  'clarity_of_thought_feedback': 'The essay "India in the Age of AI" is well-structured and presents a coherent argument regarding the potential and challenges of AI in India. The author effectively identifies India\'s strengths in AI, such as its skilled workforce and robust IT industry, while also addressing significant challenges, including the digital divide and data privacy issues. \n\nThe clarity of thought is evident in the logical progression of ideas. I appreciate how the essay begins with a strong introduction that outlines the significance of AI for India’s future. Each paragraph builds upon the previous one, transitioning smoothly between topics—strengths, applications, challenges, and solutions. The use of specific examples (like applications in agriculture and healthcare) supports the arguments made and illustrates the practical implications of AI development.\n\nHowever, there are areas where the essay could be improved for greater clarity and depth. For instance, while the job displacement issue is mentioned, it could be further elaborated to explicitly state potential solutions or initiatives that could mitigate its impact on low-skilled workers. Additionally, more extensive discussion on the ethical implications of AI, including concrete examples of potential misuse of data, would enhance the argument regarding the need for a strong regulatory framework.\n\nThe conclusion succinctly wraps up the discussion, reinforcing the dual nature of AI as both an opportunity and a challenge. However, reiterating specific actions or recommendations for stakeholders could leave the reader with a clearer sense of direction.\n\nOverall, the essay articulates the central theme well and provides a balanced view of the opportunities and challenges that AI presents to India. While there is room for improvement in expanding certain points, the writing is generally clear and informative. \n\nScore: 8/10',
#  'in_depth_analysis_feedback': 'The essay titled "India in the Age of AI" provides a comprehensive overview of the potential and challenges presented by artificial intelligence for India. The author effectively outlines India\'s strengths in the AI landscape, including its vast pool of STEM graduates and a thriving IT sector, which are essential for fostering innovation. Key examples from various domains such as agriculture, healthcare, and education are well-crafted, illustrating the practical applications of AI in improving these sectors. \n\nHowever, while the essay highlights significant strengths, it also adequately addresses the challenges facing India in adopting AI technology, such as the digital divide and data privacy issues. The discussion of socio-economic disparities and the potential for job displacement is particularly relevant, though it could benefit from more depth in terms of specific examples or case studies that demonstrate these issues in action. Additionally, while the essay mentions the need for a multi-stakeholder approach and international collaboration, it could flesh out what effective collaborations might look like and how they could be implemented. \n\nThe conclusion ties the themes together well, emphasizing the importance of responsible AI adoption. However, it may leave some readers wanting more actionable insights or specific steps that different stakeholders can take to ensure this vision is realized. Overall, the essay demonstrates a solid understanding of the topic and presents a balanced view of both the opportunities and challenges, but it could improve by offering deeper analyses in some areas and providing more concrete examples.  \n\nOverall, I would assign this essay a score of 8 out of 10. It is well structured, informative, and thought-provoking, but some areas could use further elaboration to enhance the depth of analysis.',
#  'feedback_summary': AIMessage(content='**Final Feedback Summary for the Essay "India in the Age of AI"**\n\n**Overall Impression:**\nThe essay presents an articulate exploration of the potential of artificial intelligence (AI) in India, addressing both the opportunities and challenges associated with its adoption. It is well-structured, flows logically, and maintains a formal tone appropriate for the topic.\n\n**Strengths:**\n1. **Clarity and Structure:** The essay boasts a clear introduction, body, and conclusion, with seamless transitions that maintain reader engagement.\n2. **Depth of Analysis:** A comprehensive analysis captures India’s position in the AI landscape, balancing strengths (such as a skilled workforce and government initiatives) with significant challenges (like the digital divide and data privacy).\n3. **Use of Examples:** Specific examples from agriculture and healthcare effectively illustrate the practical impact of AI in India, enhancing the argument\'s credibility.\n4. **Call to Action:** The conclusion summarizes key points and emphasizes the need for responsible AI adoption through multi-stakeholder involvement.\n\n**Areas for Improvement:**\n1. **Language Precision:** Simplifying complex phrases could enhance readability. For example, "burgeoning base" might be clearer as "growing number."\n2. **Citations and References:** Integrating credible sources, statistics, or studies to substantiate claims—especially regarding the digital divide and data privacy—would strengthen the argument.\n3. **Elaboration on Critical Topics:** Areas like data privacy and job displacement could benefit from more in-depth discussion and examples, specifically regarding potential solutions and ethical concerns.\n4. **Editing for Conciseness:** Some sentences may be overly lengthy, detracting from clarity. Breaking them into simpler statements could improve comprehension.\n\n**Score: 8/10**\nOverall, the essay demonstrates a solid understanding of AI\'s implications for India. While it effectively discusses key themes and offers balanced perspectives, there is room for improvement in the depth of certain analyses and the provision of concrete examples. Minor revisions in language and structure could further enhance the clarity and impact of the essay.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 409, 'prompt_tokens': 1139, 'total_tokens': 1548, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0.00041625, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0.00041625, 'upstream_inference_prompt_cost': 0.00017085, 'upstream_inference_completions_cost': 0.0002454}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_965c8b9ecf', 'id': 'gen-1783526435-HwCSGdoKWjXGMws3Xe3s', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4275-b10b-7723-a828-a870d451738c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1139, 'output_tokens': 409, 'total_tokens': 1548, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  'individual_score': [8, 8, 8],
#  'average_score': 8.0}

# %% [markdown]
# #### Experiment with the bad essay

# %%
essay2 = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
workflow.invoke(input={"essay":essay2})
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': 'The essay presents a clear perspective on the potential benefits and challenges of Artificial Intelligence (AI) in India. It addresses both the positive impact of AI in various sectors, such as agriculture and healthcare, and the possible negative consequences, like job displacement and privacy issues. However, several areas could be improved for better clarity and coherence.\n\n1. **Language and Grammar**: The essay contains numerous grammatical errors and awkward phrases. For example, phrases like "new tech call Artificial Intel… something (AI)" could be rephrased to "new technology called Artificial Intelligence (AI)." Additionally, the sentence structures are often fragmented and lack the necessary complexity for a more formal essay.\n\n2. **Clarity and Coherence**: Some sentences are unclear or overly simplistic. For instance, "If work hard, India can go top" would be clearer as "If India works hard, it can become a leader in AI." The overall flow of ideas can be improved by using transition words and constructing paragraphs that develop individual points more thoroughly.\n\n3. **Structure**: The essay has a basic structure with an introduction, body, and conclusion, but it could benefit from more distinct paragraphs and topic sentences for each section. This would help guide the reader through the arguments being presented.\n\n4. **Depth of Argument**: While the essay mentions important issues such as job loss and privacy, these points could be expanded with more detail or examples to substantiate the claims. Providing specific examples of AI applications in India or referencing studies on job displacement would strengthen the argument.\n\n5. **Conclusion**: The conclusion summarizes the main points well but rephrasing it to reinforce the central message clearly would enhance its impact.',
#  'clarity_of_thought_feedback': 'The essay addresses the potential impact of Artificial Intelligence (AI) in India, highlighting both the opportunities and challenges presented by this technology. The author\'s passion for the topic is evident, but the clarity of thought suffers due to several factors:\n\n1. **Language and Grammar**: The essay is riddled with grammatical errors and informal language, making it difficult to read. Phrases like "new tech call Artificial Intel… something (AI)" and "India also want become big" lack proper structure and grammar, which detracts from the overall message.\n\n2. **Vague Statements**: There are several instances of vagueness, such as "if no careful, India go back" and "one more big problem is privacy." These statements could benefit from clarification and elaboration to convey a clear understanding of the issues.\n\n3. **Organizational Flow**: The essay jumps from one idea to another without clear transitions, making it hard to follow the logic. For example, discussing technology\'s positive impacts on farming, healthcare, and schools is great but would be more effective with smoother transitions and clearer sectioning.\n\n4. **Depth of Analysis**: The essay touches on important concerns like accessibility, job loss, and privacy but lacks a deeper analysis of how these issues might be addressed or mitigated. It would be helpful to include specific examples or potential solutions alongside the problems mentioned.\n\n5. **Conclusion**: The conclusion reiterates the threats and possibilities but fails to summarize the main arguments or provide a clear call-to-action. A stronger summation would help reinforce the essay\'s main points.',
#  'in_depth_analysis_feedback': 'The essay titled "India and AI Time" presents a straightforward and basic overview of the implications of artificial intelligence (AI) in India. The writer touches on some crucial points, such as the advantages of AI in agriculture, healthcare, education, and governance, while also mentioning significant challenges like digital divide, job losses, and privacy concerns. However, the analysis lacks depth and complexity. Here are some points to consider:\n\n1. **Structure and Clarity**: The essay has a clear structure with an introduction, body paragraphs, and a conclusion. However, the grammar and sentence construction are poor, leading to a lack of coherence in certain parts. The use of simpler expressions instead of more academic language makes it sound conversational rather than analytical.\n\n2. **Depth of Analysis**: The analysis of AI\'s benefits is superficial. Although the essay lists various sectors where AI can positively impact, it does not delve deeply into how these changes can be implemented or their potential effectiveness in addressing the needs of the population. The arguments lack supporting evidence or examples, weakening the overall analysis.\n\n3. **Acknowledgment of Challenges**: While the writer acknowledges challenges such as access to technology and job displacement, these concerns are mentioned in a cursory manner. A more thorough examination of these issues, including potential solutions or comparisons with other countries\' experiences, would enhance the depth of the essay.\n\n4. **Conclusion**: The conclusion reiterates the importance of inclusive AI implementation but lacks a powerful closing statement or a call to action that would leave a lasting impression.\n\nOverall, the essay requires more analytical depth, better organization, and a careful use of language. It has the foundation for a strong argument but needs development in multiple areas to effectively communicate its message.',
#  'feedback_summary': AIMessage(content="**Final Feedback Summary for the Essay on AI in India**\n\nThe essay offers a perspective on the potential benefits and challenges of Artificial Intelligence (AI) in India, covering areas such as agriculture, healthcare, and the risks of job displacement and privacy concerns. While the author demonstrates a clear interest in the topic, multiple issues detract from the overall effectiveness of the essay. \n\n**Overall Scores:**\n\n- **Language and Grammar:** 2/5  \n  The essay is plagued by grammatical errors, awkward phrasing, and informal language, leading to difficulties in comprehension. Clearer sentence structures and correct grammar are needed to enhance readability and professionalism.\n\n- **Clarity and Coherence:** 2/5  \n  Many statements are vague and simplistic, hindering the communication of key ideas. Improved clarity through rephrasing and more complex sentence structures would benefit the essay significantly. Transitions between points are often lacking, making the flow of ideas confusing.\n\n- **Structure:** 3/5  \n  Though the essay has a recognizable structure with an introduction, body, and conclusion, it would be improved with distinct paragraphs and focused topic sentences that clearly guide the reader through each argument.\n\n- **Depth of Analysis:** 2/5  \n  The analysis of AI’s benefits is superficial and lacks substantial depth. While key issues such as job loss and privacy are mentioned, they are not explored in detail or supported by specific examples, weakening the arguments presented.\n\n- **Conclusion:** 2/5  \n  The conclusion summarizes main points but lacks strength and clarity. A more impactful closing statement or call to action would significantly enhance the overall effectiveness of the essay.\n\n**Overall Assessment: 2.2/5**\n\nIn summary, the essay has the groundwork for a compelling discussion on AI's impact in India, but it requires substantial improvement in language use, clarity, depth, and overall organization. Focusing on these areas will bolster the essay's analytical depth and make a more persuasive case for the role of AI in India.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 402, 'prompt_tokens': 1028, 'total_tokens': 1430, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0.0003954, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0.0003954, 'upstream_inference_prompt_cost': 0.0001542, 'upstream_inference_completions_cost': 0.0002412}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_810e56f10f', 'id': 'gen-1783526491-zBbJfTQ6HmW15U59Poef', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4276-8af8-72a3-85df-6959e163e8b3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1028, 'output_tokens': 402, 'total_tokens': 1430, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  'individual_score': [4, 4, 4],
#  'average_score': 4.0}
